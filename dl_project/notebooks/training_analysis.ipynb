# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Loss Analysis

# %%
loss_folder = '/home/matterj/codebases/stable_diffusion_inpainting/dl_project/output'
analysed_loss = 'val_loss_v1.npy'
loss = np.load(loss_folder + '/' + analysed_loss)
print(loss)
plt.plot(loss)
# Out:
# [1.7929822  1.79347064 1.793487   1.79332846 1.79420139 1.79363188
#  1.79350708 1.7920911  1.79337144 1.7935017  1.79486147 1.79238534
#  1.79337144 1.79374962 1.79396561 1.79376956 1.79344678 1.79479119
#  1.79435253]
